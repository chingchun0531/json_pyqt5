# %%
from urllib import request
import json
import ssl

ssl._create_default_https_context = ssl._create_unverified_context  #無需憑證
url='http://opendataap2.hl.gov.tw/resource/files/2020-08-06/59891163c0625dca12245f1fe3476bcf.json'
json_data = request.urlopen(url).read().decode('utf-8')


def Getdata():
    return json.loads(json_data)

if __name__ == '__main__':
    jsondata = json.loads(json_data)
    res= json.dumps(json_data)
    print(type(jsondata))
    print(res)
# Out:
# <class 'list'>
# ...
